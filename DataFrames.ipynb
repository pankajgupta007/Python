# %% [markdown]
# <a href="https://colab.research.google.com/github/pankajgupta007/Python/blob/main/DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
stats = pd.read_csv('/content/DemographicData.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#Number of Rows
len(stats)
# Out:
# 195

# %%
#See Column
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#Number of columns
len(stats.columns)
# Out:
# 5

# %%
#Top rows
stats.head() #by default it returns 5 if we don't enter any value
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Bottom rows
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#information of columns
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#statistics on dataframes
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
  stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns = ['Countryname','CountryCode','Birthrate','InternetUsers','IncomeGroup']

# %%
stats.head()
# Out:
#             Countryname CountryCode  Birthrate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#rows
stats[20:23]
# Out:
#    Countryname CountryCode  Birthrate  InternetUsers          IncomeGroup
# 20     Belarus         BLR     12.500          54.17  Upper middle income
# 21      Belize         BLZ     23.092          33.60  Upper middle income
# 22     Bermuda         BMU     10.400          95.30          High income

# %%
#columns
stats.columns[2:4]
# Out:
# Index(['Birthrate', 'InternetUsers'], dtype='object')

# %%
stats[:7] #from 0 to 6
# Out:
#             Countryname CountryCode  Birthrate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats[188:] #from specified rows till the end
# Out:
#             Countryname CountryCode  Birthrate  InternetUsers  \
# 188  West Bank and Gaza         PSE     30.394           46.6
# 189               Samoa         WSM     26.172           15.3
# 190         Yemen, Rep.         YEM     32.947           20.0
# 191        South Africa         ZAF     20.850           46.5
# 192    Congo, Dem. Rep.         COD     42.394            2.2
# 193              Zambia         ZMB     40.471           15.4
# 194            Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats[::-1] #rows subsetting
# Out:
#               Countryname CountryCode  Birthrate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
#columns subsetting

# %%
stats['Countryname'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Countryname, dtype: object

# %%
stats[['Birthrate','Countryname']].head()
# Out:
#    Birthrate           Countryname
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
stats.CountryCode.head() #dataframe.column.function()
# Out:
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    ARE
# Name: CountryCode, dtype: object

# %%
#subsetting rows and columns
stats[4:8][['Birthrate','Countryname']]
# Out:
#    Birthrate           Countryname
# 4     11.044  United Arab Emirates
# 5     17.716             Argentina
# 6     13.308               Armenia
# 7     16.447   Antigua and Barbuda

# %%
stats[['Birthrate','Countryname']][4:8]
# Out:
#    Birthrate           Countryname
# 4     11.044  United Arab Emirates
# 5     17.716             Argentina
# 6     13.308               Armenia
# 7     16.447   Antigua and Barbuda

# %%
result = stats.InternetUsers / stats.Birthrate

# %%
result.head()
# Out:
# 0    7.702070
# 1    0.167362
# 2    0.415353
# 3    4.442028
# 4    7.968127
# dtype: float64

# %%
stats['NewColumn'] = stats.InternetUsers / stats.Birthrate

# %%
stats.head()
# Out:
#             Countryname CountryCode  Birthrate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  NewColumn
# 0          High income   7.702070
# 1           Low income   0.167362
# 2  Upper middle income   0.415353
# 3  Upper middle income   4.442028
# 4          High income   7.968127

# %%
newstats = stats.drop('NewColumn',1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
newstats.head()
# Out:
#             Countryname CountryCode  Birthrate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
Filter = stats.InternetUsers < 2

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[Filter]
# Out:
#       Countryname CountryCode  Birthrate  InternetUsers          IncomeGroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#      NewColumn
# 11    0.029444
# 52    0.025862
# 55    0.057707
# 64    0.042853
# 117   0.088305
# 127   0.034232
# 154   0.046285
# 156   0.034176
# 172   0.030765

# %%
stats[stats.InternetUsers < 2]
# Out:
#       Countryname CountryCode  Birthrate  InternetUsers          IncomeGroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#      NewColumn
# 11    0.029444
# 52    0.025862
# 55    0.057707
# 64    0.042853
# 117   0.088305
# 127   0.034232
# 154   0.046285
# 156   0.034176
# 172   0.030765

# %%
#Multiple Filter
stats [(stats.InternetUsers<2) & (stats.Birthrate>40)]
# Out:
#     Countryname CountryCode  Birthrate  InternetUsers IncomeGroup  NewColumn
# 11      Burundi         BDI     44.151            1.3  Low income   0.029444
# 127       Niger         NER     49.661            1.7  Low income   0.034232
# 156     Somalia         SOM     43.891            1.5  Low income   0.034176

# %%
#Getting Unique Categories
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
#.at
#.iat

# %%
stats.iat[1,4]
# Out:
# 'Low income'

# %%
stats.iat[1,1]
# Out:
# 'AFG'

# %%
stats.at[2,'InternetUsers']
# Out:
# 19.1

# %%
subset1=stats[::10]

# %%
subset1
# Out:
#      Countryname CountryCode  Birthrate  InternetUsers          IncomeGroup  \
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
subset1.iat[10,0]
# Out:
# 'Libya'

# %%
subset1.at[10,'Countryname']
# Out:
# 'Azerbaijan'

# %%
subset1.iat[5,0]
# Out:
# 'Ecuador'

# %%
subset1.at[10,'Countryname']
# Out:
# 'Azerbaijan'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']= 8,8
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(stats['InternetUsers'])

# %%
visual1 = sns.distplot(stats['InternetUsers'],bins=40)

# %%
#BOXPLOT
visualbox1=sns.boxplot(data=stats, x='IncomeGroup', y='Birthrate')
plt.rcParams['figure.figsize'] = 8,4

# %%
visualbox3=sns.lmplot(data=stats, x='InternetUsers', y='Birthrate')

# %%
visualbox4=sns.distplot(stats['Birthrate'], bins=10)

# %%
visualbox5=sns.lmplot(data=stats,x='InternetUsers', y='Birthrate', fit_reg=False)

# %%
visualbox5 = sns.lmplot(data=stats,x='InternetUsers', y='Birthrate', fit_reg=False, hue='IncomeGroup', scatter_kws={'s':200})

# %%
stats.head()
# Out:
#             Countryname CountryCode  Birthrate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  NewColumn
# 0          High income   7.702070
# 1           Low income   0.167362
# 2  Upper middle income   0.415353
# 3  Upper middle income   4.442028
# 4          High income   7.968127

# %%
stats.to_excel("output.xlsx")
